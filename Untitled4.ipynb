# %% [markdown]
# <a href="https://colab.research.google.com/github/Bobbysolomon/Regression/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as p
import matplotlib.pyplot as m
import numpy as n
d=p.read_csv('Salary_Data.csv')
x=d.iloc[:,:-1].values
y=d.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split as t
x_tr,x_te,y_tr,y_te=t(x,y,test_size=1/3,random_state=0 )

# %%
from sklearn.linear_model import LinearRegression as lr
g=lr()
g.fit(x_tr,y_tr)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
q=g.predict(x_te)

# %%
m.scatter(x_tr,y_tr)
m.plot(x_tr,g.predict(x_tr),color="red")
m.show()

# %%
m.scatter(x_te,y_te,color="blue")
m.plot(x_te,g.predict(x_te),color="red")
m.xlabel("Experince")
m.title("Testing the values")
m.ylabel("Salary")
m.show()
